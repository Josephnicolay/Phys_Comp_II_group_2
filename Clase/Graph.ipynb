# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("Epochs.txt",sep="\s+")
data.head()
# Out:
#           0   0.1          1          2          3          4          5  \
# 0   0.00000   1.0   1.100000   1.200000   1.300000   1.400000   1.500000
# 1  -1.33333  17.0  16.899809  16.857790  16.863749  16.909624  16.989029
# 2 -16.20610  17.0  15.555667  14.406709  13.488167  12.754356  12.172254
# 3 -14.11610  17.0  15.744997  14.754146  13.971049  13.355456  12.877869
# 4 -14.00150  17.0  15.755382  14.773181  13.997463  13.388270  12.916300
#
#            6          7          8  ...         11         12         13  \
# 0   1.600000   1.700000   1.800000  ...   2.100000   2.200000   2.300000
# 1  17.096916  17.229315  17.383139  ...  17.952414  18.173801  18.409861
# 2  11.717429  11.371449  11.120161  ...  10.835077  10.872576  10.967652
# 3  12.516180  12.253495  12.076683  ...  11.967748  12.049226  12.181208
# 4  12.559573  12.301284  12.128360  ...  12.028404  12.112056  12.245827
#
#           14         15         16         17         18         19         20
# 0   2.400000   2.500000   2.600000   2.700000   2.800000   2.900000   3.000000
# 1  18.660368  18.925337  19.204975  19.499645  19.809837  20.136137  20.479202
# 2  11.116400  11.315507  11.562120  11.853745  12.188163  12.563370  12.977532
# 3  12.359916  12.582174  12.845293  13.146978  13.485258  13.858429  14.265009
# 4  12.425953  12.649272  12.913108  13.215181  13.553538  13.926495  14.332590
#
# [5 rows x 22 columns]

# %%
nData = data.transpose()
nData.head()
# Out:
#        0          1          2          3          4          5
# 0    0.0  -1.333330 -16.206100 -14.116100 -14.001500 -14.000200
# 0.1  1.0  17.000000  17.000000  17.000000  17.000000  17.000000
# 1    1.1  16.899809  15.555667  15.744997  15.755382  15.755495
# 2    1.2  16.857790  14.406709  14.754146  14.773181  14.773389
# 3    1.3  16.863749  13.488167  13.971049  13.997463  13.997751

# %%
def lineSlope(x,x0,y0,m):
    return m*x+(y0-m*x0)

def sol(x):
    return x**2 + 16/x

# %%
t = np.linspace(0.75,1.25)
t2 = np.linspace(1.0,3.0)
fig, ax = subplots(1,5,figsize=(17,3))
for i in range(0,5):
    ax[i].plot(t2,sol(t2), 'r',label="SolExacta")
    ax[i].plot(t,lineSlope(t,nData[0][1], 17.0, nData[i+1][0]), '--',label=nData[i+1][0])
    ax[i].plot(nData[0][1:], nData[i+1][1:], 'go')
    ax[i].grid()
    ax[i].legend()
