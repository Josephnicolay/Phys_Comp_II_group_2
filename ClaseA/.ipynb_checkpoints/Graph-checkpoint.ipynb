# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("Epochs.txt",sep="\s+")
data.head()
# Out:
#           0   0.1          1          2          3          4          5  \
# 0   0.00000   1.0   1.100000   1.200000   1.300000   1.400000   1.500000
# 1  -1.33333  17.0  16.899809  16.857790  16.863749  16.909624  16.989029
# 2 -16.20580  17.0  15.555688  14.406748  13.488221  12.754424  12.172333
# 3 -14.11590  17.0  15.745015  14.754179  13.971095  13.355513  12.877934
# 4 -14.00150  17.0  15.755381  14.773179  13.997459  13.388266  12.916294
#
#            6          7          8    ...             11         12  \
# 0   1.600000   1.700000   1.800000    ...       2.100000   2.200000
# 1  17.096916  17.229315  17.383139    ...      17.952414  18.173801
# 2  11.717519  11.371548  11.120269    ...      10.835206  10.872709
# 3  12.516254  12.253577  12.076772    ...      11.967851  12.049333
# 4  12.559566  12.301276  12.128351    ...      12.028396  12.112047
#
#           13         14         15         16         17         18  \
# 0   2.300000   2.400000   2.500000   2.600000   2.700000   2.800000
# 1  18.409861  18.660368  18.925337  19.204975  19.499645  19.809837
# 2  10.967791  11.116542  11.315652  11.562268  11.853895  12.188313
# 3  12.181317  12.360027  12.582288  12.845408  13.147094  13.485373
# 4  12.245818  12.425944  12.649263  12.913099  13.215173  13.553530
#
#           19         20
# 0   2.900000   3.000000
# 1  20.136137  20.479202
# 2  12.563520  12.977682
# 3  13.858543  14.265122
# 4  13.926486  14.332582
#
# [5 rows x 22 columns]

# %%
nData = data.transpose()
nData.head()
# Out:
#        0          1          2          3          4          5
# 0    0.0  -1.333330 -16.205800 -14.115900 -14.001500 -14.000200
# 0.1  1.0  17.000000  17.000000  17.000000  17.000000  17.000000
# 1    1.1  16.899809  15.555688  15.745015  15.755381  15.755495
# 2    1.2  16.857790  14.406748  14.754179  14.773179  14.773389
# 3    1.3  16.863749  13.488221  13.971095  13.997459  13.997751

# %%
def lineSlope(x,x0,y0,m):
    return m*x+(y0-m*x0)

def sol(x):
    return x**2 + 16/x

# %%
t = np.linspace(0.75,1.25)
t2 = np.linspace(1.0,3.0)
fig, ax = subplots(1,5,figsize=(17,3))
for i in range(0,5):
    ax[i].plot(t2,sol(t2), 'r',label="SolExacta")
    ax[i].plot(t,lineSlope(t,nData[0][1], 17.0, nData[i+1][0]), '--',label=nData[i+1][0])
    ax[i].plot(nData[0][1:], nData[i+1][1:], 'go')
    ax[i].grid()
    ax[i].legend()
