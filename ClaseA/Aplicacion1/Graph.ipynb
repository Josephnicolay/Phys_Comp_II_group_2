# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("Epochs.txt",sep="\s+")
data.head()
# Out:
#           0  0.1         1         2         3         4         5         6  \
# 0  0.000000  0.0  0.333333  0.666667  1.000000  1.333333  1.666667  2.000000
# 1  1.000000  0.0  0.327189  0.619272  0.847723  0.993633  1.046990  1.004593
# 2  0.929974  0.0  0.304274  0.575786  0.787574  0.921346  0.967195  0.922060
# 3  0.924303  0.0  0.302418  0.572266  0.782711  0.915518  0.960796  0.915498
# 4  0.924463  0.0  0.302470  0.572365  0.782848  0.915682  0.960976  0.915682
#
#           7         8    ...            21        22        23        24  \
# 0  2.333333  2.666667    ...      7.000000  7.333333  7.666667  8.000000
# 1  0.868966  0.649234    ...      0.253773  0.556740  0.801832  0.967885
# 2  0.788954  0.577726    ...      0.299574  0.571801  0.784674  0.919762
# 3  0.782672  0.572215    ...      0.302478  0.572272  0.782663  0.915420
# 4  0.782849  0.572370    ...      0.302398  0.572260  0.782720  0.915542
#
#          25        26        27        28        29         30
# 0  8.333334  8.666667  9.000000  9.333334  9.666667  10.000000
# 1  1.043022  1.022633  0.907920  0.706323  0.433474   0.114703
# 2  0.967035  0.923334  0.791574  0.581485  0.311148   0.007342
# 3  0.960654  0.915320  0.782472  0.572008  0.302170  -0.000202
# 4  0.960833  0.915546  0.782727  0.572273  0.302421   0.000008
#
# [5 rows x 32 columns]

# %%
nData = data.transpose()
nData.head()
# Out:
#             0         1         2         3         4
# 0    0.000000  1.000000  0.929974  0.924303  0.924463
# 0.1  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.333333  0.327189  0.304274  0.302418  0.302470
# 2    0.666667  0.619272  0.575786  0.572266  0.572365
# 3    1.000000  0.847723  0.787574  0.782711  0.782848

# %%
nData[1][1]
# Out:
# 0.0

# %%
def lineSlope(x,x0,y0,m):
    return m*x+(y0-m*x0)

def sol(x):
    return x**2 + 16/x

# %%
t = np.linspace(-0.5,0.5)
t2 = np.linspace(1.0,3.0)
fig, ax = subplots(1,4,figsize=(17,3))
for i in range(0,4):
    #ax[i].plot(t2,sol(t2), 'r',label="SolExacta")
    ax[i].plot(t,lineSlope(t,nData[0][1], nData[1][1], nData[i+1][0]), '--',label=nData[i+1][0])
    ax[i].plot(nData[0][1:], nData[i+1][1:], 'go')
    ax[i].grid()
    ax[i].legend()

fig.savefig('t0_2')
